# %%
# Libraries/Packages

import time
import pandas as pd
import torch
import serial # required pyserial install
import brainflow
from sklearn.preprocessing import StandardScaler
from brainflow.board_shim import BoardShim, BrainFlowInputParams, BoardIds
from serial.tools import list_ports

from predictions_local.brainflowprocessor import BrainFlowDataProcessor

# %%
# Get Synthetic Data as Tensor

synthetic_processor = BrainFlowDataProcessor(board_id=BoardIds.SYNTHETIC_BOARD.value)
X_synthetic_tensor = synthetic_processor.get_tensor()
print(X_synthetic_tensor)
# Out:
# [2025-11-15 20:25:22.862] [board_logger] [info] incoming json: {
#     "file": "",
#     "file_anc": "",
#     "file_aux": "",
#     "ip_address": "",
#     "ip_address_anc": "",
#     "ip_address_aux": "",
#     "ip_port": 0,
#     "ip_port_anc": 0,
#     "ip_port_aux": 0,
#     "ip_protocol": 0,
#     "mac_address": "",
#     "master_board": -100,
#     "other_info": "",
#     "serial_number": "",
#     "serial_port": "",
#     "timeout": 0
# }
# [2025-11-15 20:25:22.862] [board_logger] [trace] Board object created -1
# tensor([[ 1.7802e-01,  3.9117e-01,  6.5753e-01,  ...,  1.8769e+00,
#           1.6811e+00,  1.4322e+00],
#         [ 3.3796e-01,  7.2572e-01,  9.5558e-01,  ..., -9.6516e-01,
#          -1.1376e+00, -1.3273e+00],
#         [ 4.9962e-01,  1.0752e+00,  1.2328e+00,  ..., -6.0518e-01,
#          -4.6455e-02,  4.6872e-01],
#         ...,
#         [-1.6955e-01, -2.9276e-01, -4.3050e-01,  ..., -1.4689e+00,
#          -1.2966e+00, -1.8320e+00],
# ...

# %%
# Get Synthetic Data as df

X_synthetic_df= synthetic_processor.eeg_df
print(X_synthetic_df)
# Out:
#          EEG_1      EEG_2      EEG_3       EEG_4       EEG_5       EEG_6  \
# 0    11.773467  27.924606  49.772280   71.401229  112.899921  110.382642
# 1    13.369835  34.629124  58.740932   91.003910  110.394327  137.757317
# 2    14.983411  41.633273  67.083224  105.654463  110.096371  111.937012
# 3    16.822707  43.751132  66.454085   88.236262   73.106309   50.761280
# 4    18.296135  47.005717  73.349913   70.079900   37.792313    0.228195
# ..         ...        ...        ...         ...         ...         ...
# 496   4.650246   1.474713  -2.433118  -19.393915   -7.595737  -38.700338
# 497   6.371768   7.557199   4.921359    0.592177  -14.448467  -31.364765
# 498   8.304305  14.218460  17.031936   18.059939   24.066540   28.673076
# 499  10.000000  21.339875  34.221020   47.068233   61.499550   75.055743
# 500  11.812986  27.943236  51.807674   76.696946  109.120076  135.285750
#
#           EEG_7       EEG_8       EEG_9      EEG_10      EEG_11      EEG_12  \
# ...

# %% [markdown]
# ### Require Testing w/ Live Brainwave reading

# %%
# Cyton board (auto-detect serial port)
cyton_processor = BrainFlowDataProcessor(board_id=BoardIds.CYTON_BOARD.value)
X_cyton = cyton_processor.get_tensor()

# %%
# Cyton Daisy board (auto-detect serial port)
daisy_processor = BrainFlowDataProcessor(board_id=BoardIds.CYTON_DAISY_BOARD.value)
X_daisy = daisy_processor.get_tensor()
