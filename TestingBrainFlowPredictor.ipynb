# %%
# Libraries/Packages

import time
import pandas as pd
import torch
import serial # required pyserial install
import brainflow
from sklearn.preprocessing import StandardScaler
from brainflow.board_shim import BoardShim, BrainFlowInputParams, BoardIds
from serial.tools import list_ports

from predictions_local.brainflowprocessor import BrainFlowDataProcessor

# %%
# Get Synthetic Data as Tensor

synthetic_processor = BrainFlowDataProcessor(board_id=BoardIds.SYNTHETIC_BOARD.value)
X = synthetic_processor.get_tensor()
print(X)
# Out:
# [2025-11-15 20:25:39.530] [board_logger] [info] incoming json: {
#     "file": "",
#     "file_anc": "",
#     "file_aux": "",
#     "ip_address": "",
#     "ip_address_anc": "",
#     "ip_address_aux": "",
#     "ip_port": 0,
#     "ip_port_anc": 0,
#     "ip_port_aux": 0,
#     "ip_protocol": 0,
#     "mac_address": "",
#     "master_board": -100,
#     "other_info": "",
#     "serial_number": "",
#     "serial_port": "",
#     "timeout": 0
# }
# [2025-11-15 20:25:39.530] [board_logger] [trace] Board object created -1
# tensor([[ 0.1821,  0.4541,  0.6843,  ...,  1.8576,  1.9495,  1.1872],
#         [ 0.3557,  0.6835,  1.0855,  ..., -0.7847, -1.9772, -0.8176],
#         [ 0.5059,  1.0937,  1.4823,  ..., -0.4098, -0.0633,  0.4657],
#         ...,
#         [-0.0023,  0.0731,  0.1555,  ...,  0.1248,  0.1044,  0.0646],
#         [ 0.1820,  0.3830,  0.5971,  ...,  0.4199,  0.2166,  0.4902],
#         [ 0.3360,  0.6865,  0.9644,  ..., -1.5765, -1.7102, -1.4966]])

# %%
from predictions_local.deeplearningpytorchpredictor import DeeplearningPytorchPredictor

model = DeeplearningPytorchPredictor()

pred_label = model(X)
print(pred_label)
# Out:
# right
